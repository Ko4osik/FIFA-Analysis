# %% [markdown]
# ## EDA данных

# %% [markdown]
# ### Table of Contents
#
# * [Импорт данных](#Импорт-данных)
# * [Описание столбцов](#Описание-столбцов)
# * [Анализ и визуализация данных](#Анализ-и-визуализация-данных)
# * [Кодирование данных](#Кодирование-данных)

# %% [markdown]
# ### Импорт данных

# %%
import pandas as pd
import numpy as np
# Загружаем данные, полученные в результате парсинга
csv_file_path = "players.csv"
df = pd.read_csv(csv_file_path)

df
# Out:
#       Unnamed: 0             Name Card Type    Nation             Club League  \
# 0              0   Erling Haaland      TOTS    Norway  Manchester City  ENG 1
# 1              1  Kevin De Bruyne      TOTS   Belgium  Manchester City  ENG 1
# 2              2  Kevin De Bruyne      TOTY   Belgium  Manchester City  ENG 1
# 3              3    Mohamed Salah      TOTS     Egypt        Liverpool  ENG 1
# 4              4       Ruben Dias      TOTS  Portugal  Manchester City  ENG 1
# ...          ...              ...       ...       ...              ...    ...
# 1582        1582   Miroslav Klose      Icon   Germany            Icons    ICO
# 1583        1583  Michael Ballack      Icon   Germany            Icons    ICO
# 1584        1584     Hugo Sanchez      Icon    Mexico            Icons    ICO
# 1585        1585      Bobby Moore      Icon   England            Icons    ICO
# 1586        1586    David Beckham      Icon   England            Icons    ICO
#
#       Skills  W/F  W/R   Foot  ...  Composure Interceptions Heading Acc.  \
# 0          4    5  H/M   Left  ...         96            54           98
# 1          4    5  H/H  Right  ...         97            88           73
# 2          4    5  H/H  Right  ...         96            85           70
# 3          5    3  H/M   Left  ...         99            66           70
# 4          2    4  M/H  Right  ...         99            94           96
# ...      ...  ...  ...    ...  ...        ...           ...          ...
# 1582       3    4  H/M  Right  ...         88            51           92
# 1583       4    4  M/H  Right  ...         85            81           86
# 1584       3    4  H/M   Left  ...         82            41           90
# 1585       2    3  M/M  Right  ...         94            93           86
# 1586       3    3  H/H  Right  ...         90            67           72
#
#      Def. Awareness Stand Tackle Slide Tackle  Jumping  Stamina  Strength  \
# 0                55           66           36       82       89        99
# 1                90           86           70       71       99        84
# 2                86           82           67       70       97        84
# 3                46           52           48       76       96        83
# 4                99           98           94       87       92        99
# ...             ...          ...          ...      ...      ...       ...
# 1582             24           39           38       93       77        82
# 1583             73           80           75       87       91        86
# 1584             34           34           32       85       75        70
# 1585             93           91           90       81       88        82
# 1586             65           69           67       72       91        75
#
#       Aggression
# 0             94
# 1             85
# 2             83
# 3             70
# 4             99
# ...          ...
# 1582          65
# 1583          89
# 1584          61
# 1585          80
# 1586          79
#
# [1587 rows x 53 columns]

# %%
# Удаляем индекс как несущественный признак
df = df.reset_index(drop=True)
df = df.drop('Unnamed: 0', axis=1)

# %%
# Обзорные данные о числовых признаках
df.describe()
# Out:
#             Skills          W/F          Age       Rating          PAC  \
# count  1587.000000  1587.000000  1587.000000  1587.000000  1587.000000
# mean      3.504726     3.635791    31.628859    86.603655    83.860744
# std       0.859893     0.780228    11.998276     4.850716     9.069656
# min       2.000000     1.000000     0.000000    73.000000    31.000000
# 25%       3.000000     3.000000    24.000000    85.000000    80.000000
# 50%       4.000000     4.000000    28.000000    87.000000    85.000000
# 75%       4.000000     4.000000    34.000000    90.000000    90.000000
# max       5.000000     5.000000    95.000000    98.000000    99.000000
#
#                SHO          PAS          DRI          DEF          PHY  ...  \
# count  1587.000000  1587.000000  1587.000000  1587.000000  1587.000000  ...
# mean     77.202268    80.057971    83.852552    63.841840    79.078765  ...
# std      13.524488     8.163087     7.728262    19.492672     8.308869  ...
# min      29.000000    45.000000    49.000000    22.000000    45.000000  ...
# 25%      71.000000    75.000000    80.000000    45.000000    74.000000  ...
# 50%      82.000000    81.000000    85.000000    65.000000    80.000000  ...
# 75%      87.000000    86.000000    89.000000    82.500000    85.000000  ...
# max      99.000000    99.000000    99.000000    97.000000    99.000000  ...
#
#          Composure  Interceptions  Heading Acc.  Def. Awareness  Stand Tackle  \
# count  1587.000000    1587.000000   1587.000000     1587.000000   1587.000000
# mean     84.802773      63.505356     74.429112       62.548204     63.327662
# std       6.796505      22.036435     14.651754       21.188505     22.561554
# min      59.000000      15.000000     29.000000       18.000000     16.000000
# 25%      81.000000      43.000000     64.000000       44.000000     42.000000
# 50%      85.000000      68.000000     76.000000       65.000000     68.000000
# 75%      90.000000      84.000000     86.000000       82.000000     85.000000
# max      99.000000      97.000000     99.000000       99.000000     98.000000
#
#        Slide Tackle      Jumping      Stamina     Strength   Aggression
# count   1587.000000  1587.000000  1587.000000  1587.000000  1587.000000
# mean      58.933207    77.380592    84.575929    78.276623    74.540643
# std       23.419860    12.811223     8.337596    11.085747    13.649507
# min       14.000000    31.000000    50.000000    33.000000    22.000000
# 25%       37.000000    70.000000    80.000000    71.000000    65.000000
# 50%       61.000000    80.000000    85.000000    80.000000    77.000000
# 75%       81.000000    87.000000    90.000000    86.000000    85.000000
# max       99.000000    99.000000    99.000000    99.000000    99.000000
#
# [8 rows x 40 columns]

# %%
# Поиск дубликатов
df.duplicated().sum()
# Out:
# 5

# %%
# Удаление дубликатов
df = df.drop_duplicates()

# %% [markdown]
# ### Описание столбцов

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1582 entries, 0 to 1586
# Data columns (total 52 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            1582 non-null   object
#  1   Card Type       1582 non-null   object
#  2   Nation          1582 non-null   object
#  3   Club            1582 non-null   object
#  4   League          1582 non-null   object
#  5   Skills          1582 non-null   int64
#  6   W/F             1582 non-null   int64
#  7   W/R             1582 non-null   object
#  8   Foot            1582 non-null   object
#  9   Age             1582 non-null   int64
#  10  Height          1582 non-null   object
#  11  Weight          1582 non-null   object
#  12  Body Type       1582 non-null   object
#  13  Position        1582 non-null   object
#  14  Alt. Position   1582 non-null   object
#  15  Rating          1582 non-null   int64
#  16  PAC             1582 non-null   int64
#  17  SHO             1582 non-null   int64
#  18  PAS             1582 non-null   int64
#  19  DRI             1582 non-null   int64
#  20  DEF             1582 non-null   int64
#  21  PHY             1582 non-null   int64
#  22  Price           1582 non-null   int64
#  23  Acceleration    1582 non-null   int64
#  24  Sprint Speed    1582 non-null   int64
#  25  Positioning     1582 non-null   int64
#  26  Finishing       1582 non-null   int64
#  27  Shot Power      1582 non-null   int64
#  28  Long Shots      1582 non-null   int64
#  29  Volleys         1582 non-null   int64
#  30  Penalties       1582 non-null   int64
#  31  Vision          1582 non-null   int64
#  32  Crossing        1582 non-null   int64
#  33  FK. Acc.        1582 non-null   int64
#  34  Short Pass      1582 non-null   int64
#  35  Long Pass       1582 non-null   int64
#  36  Curve           1582 non-null   int64
#  37  Agility         1582 non-null   int64
#  38  Balance         1582 non-null   int64
#  39  Reactions       1582 non-null   int64
#  40  Ball Control    1582 non-null   int64
#  41  Dribbling       1582 non-null   int64
#  42  Composure       1582 non-null   int64
#  43  Interceptions   1582 non-null   int64
#  44  Heading Acc.    1582 non-null   int64
#  45  Def. Awareness  1582 non-null   int64
#  46  Stand Tackle    1582 non-null   int64
#  47  Slide Tackle    1582 non-null   int64
#  48  Jumping         1582 non-null   int64
#  49  Stamina         1582 non-null   int64
#  50  Strength        1582 non-null   int64
#  51  Aggression      1582 non-null   int64
# dtypes: int64(40), object(12)
# memory usage: 655.0+ KB

# %%
df.columns #посмотрим на получившиеся столбцы
# Out:
# Index(['Name', 'Card Type', 'Nation', 'Club', 'League', 'Skills', 'W/F', 'W/R',
#        'Foot', 'Age', 'Height', 'Weight', 'Body Type', 'Position',
#        'Alt. Position', 'Rating', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY',
#        'Price', 'Acceleration', 'Sprint Speed', 'Positioning', 'Finishing',
#        'Shot Power', 'Long Shots', 'Volleys', 'Penalties', 'Vision',
#        'Crossing', 'FK. Acc.', 'Short Pass', 'Long Pass', 'Curve', 'Agility',
#        'Balance', 'Reactions', 'Ball Control', 'Dribbling', 'Composure',
#        'Interceptions', 'Heading Acc.', 'Def. Awareness', 'Stand Tackle',
#        'Slide Tackle', 'Jumping', 'Stamina', 'Strength', 'Aggression'],
#       dtype='object')

# %%
''' 
'Name': Имя игрока.
'Card Type': Тип карты игрока.
'Nation': Нация игрока.
'Club': Клуб игрока.
'League': Лига игрока.
'Skills': Уровень навыков игрока.
'W/F': Уровень слабой ноги игрока.
'W/R': Работоспособность игрока в атаке/защите
'Foot': Предпочитаемая нога игрока.
'Age': Возраст игрока.
'Height': Рост игрока.
'Weight': Вес игрока.
'Body Type': Тип телосложения игрока.
'Position': Основная позиция игрока.
'Alt. Position': Альтернативная позиция игрока.
'Rating': Общий рейтинг игрока.
'PAC': Показатель скорости игрока.
'SHO': Показатель удара игрока.
'PAS': Показатель паса игрока.
'DRI': Показатель дриблинга игрока.
'DEF': Показатель защиты игрока.
'PHY': Показатель физических характеристик игрока.
'Price': Цена игрока.
'Acceleration': Показатель ускорения игрока.
'Sprint Speed': Показатель скорости игрока.
'Positioning': Показатель позиционирования игрока.
'Finishing': Показатель завершения игрока.
'Shot Power': Показатель силы удара игрока.
'Long Shots': Показатель дальних ударов игрока.
'Volleys': Показатель волей игрока.
'Penalties': Показатель пенальти игрока.
'Vision': Показатель обзорности игры игрока.
'Crossing': Показатель перекладины игрока.
'FK. Acc.': Показатель точности ударов с фрик-таков игрока.
'Short Pass': Показатель коротких пасов игрока.
'Long Pass': Показатель дальних пасов игрока.
'Curve': Показатель кривых ударов игрока.
'Agility': Показатель проворства игрока.
'Balance': Показатель равновесия игрока.
'Reactions': Показатель реакций
'Ball Control': Показатель контроля мяча игрока.
'Dribbling': Показатель дриблинга игрока.
'Composure': Показатель спокойствия игрока.
'Interceptions': Показатель перехватов игрока.
'Heading Acc.': Показатель точности головы игрока.
'Def. Awareness': Показатель осведомленности в обороне игрока.
'Stand Tackle': Показатель стоячих отборов игрока.
'Slide Tackle': Показатель горизонтальных отборов игрока.
'Jumping': Показатель прыжков игрока.
'Stamina': Показатель выносливости игрока.
'Strength': Показатель силы игрока.
'Aggression': Показатель агрессии игрока.
''' 

print()

# %% [markdown]
# - После анализа форматов столбцов, было замечено, что столбцы "Height" и "Weight" представлены в формате object
# - Эти столбцы должны иметь формат int-64 и представлять из себя числовые признаки

# %%
# Посмотрим, почему в столце Height данные хранятся в формате object
df.Height.head()
# Out:
# 0     6' 5"
# 1    5' 11"
# 2    5' 11"
# 3     5' 9"
# 4     6' 2"
# Name: Height, dtype: object

# %%
# Приведем данные в столбце Height к числовому формату
df['Height'] = df['Height'].str.replace("'", "").str.replace('"', '')
df['Height'] = df['Height'].apply(lambda x: round((int(x.split(' ')[0]) * 30.48 + int(x.split(' ')[1]) * 2.54))).astype(int)
df.Height.head()
# Out:
# 0    196
# 1    180
# 2    180
# 3    175
# 4    188
# Name: Height, dtype: int64

# %%
# Посмотрим, почему в столце Weight данные хранятся в формате object
df['Weight'].head()
# Out:
# 0    94kg
# 1    70kg
# 2    70kg
# 3    71kg
# 4    82kg
# Name: Weight, dtype: object

# %%
# Приведем данные в столбце Weight к числовому формату
df['Weight'] = df['Weight'].str.replace("kg", '').astype(int)
df['Weight'].head()
# Out:
# 0    94
# 1    70
# 2    70
# 3    71
# 4    82
# Name: Weight, dtype: int64

# %%
# Посмотрим на пропуски
df.isna().sum()
# Out:
# Name              0
# Card Type         0
# Nation            0
# Club              0
# League            0
# Skills            0
# W/F               0
# W/R               0
# Foot              0
# Age               0
# Height            0
# Weight            0
# Body Type         0
# Position          0
# Alt. Position     0
# Rating            0
# PAC               0
# SHO               0
# PAS               0
# DRI               0
# DEF               0
# PHY               0
# Price             0
# Acceleration      0
# Sprint Speed      0
# Positioning       0
# Finishing         0
# Shot Power        0
# Long Shots        0
# Volleys           0
# Penalties         0
# Vision            0
# Crossing          0
# FK. Acc.          0
# Short Pass        0
# Long Pass         0
# Curve             0
# Agility           0
# Balance           0
# Reactions         0
# Ball Control      0
# Dribbling         0
# Composure         0
# Interceptions     0
# Heading Acc.      0
# Def. Awareness    0
# Stand Tackle      0
# Slide Tackle      0
# Jumping           0
# Stamina           0
# Strength          0
# Aggression        0
# dtype: int64

# %%
# Заменим рабочую ногу на самое часто встречающееся значение
df['Foot'].fillna(df['Foot'].value_counts().index[0], inplace = True)

# %%
# Также там есть странное значение, поменяем его
df['Foot'].replace('REight', 'Right', inplace = True)
df['Foot'].value_counts()
# Out:
# Right    1212
# Left      370
# Name: Foot, dtype: int64

# %%
# Посмотрим на нулевые значения
(df == 0).sum()
# Out:
# Name                0
# Card Type           0
# Nation              0
# Club                0
# League              0
# Skills              0
# W/F                 0
# W/R                 0
# Foot                0
# Age                12
# Height              0
# Weight              3
# Body Type           0
# Position            0
# Alt. Position       0
# Rating              0
# PAC                 0
# SHO                 0
# PAS                 0
# DRI                 0
# DEF                 0
# PHY                 0
# Price             352
# Acceleration        0
# Sprint Speed        0
# Positioning         0
# Finishing           0
# Shot Power          0
# Long Shots          0
# Volleys             0
# Penalties           0
# Vision              0
# Crossing            0
# FK. Acc.            0
# Short Pass          0
# Long Pass           0
# Curve               0
# Agility             0
# Balance             0
# Reactions           0
# Ball Control        0
# Dribbling           0
# Composure           0
# Interceptions       0
# Heading Acc.        0
# Def. Awareness      0
# Stand Tackle        0
# Slide Tackle        0
# Jumping             0
# Stamina             0
# Strength            0
# Aggression          0
# dtype: int64

# %%
# Руками поменяем возраст, рост и вес игроков
df.loc[df['Age'] == 0, 'Age'] = [44, 49, 74, 52, 48, 58, 80, 43, 38, 57, 50, 46, 25, 25]
df.loc[df['Height'] == 0, 'Height'] = [175, 175, 181]
df.loc[df['Weight'] == 0, 'Weight'] = [86, 71, 76, 69, 69, 80]

df.Age.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [92], in <cell line: 3>()
#       1 # Руками поменяем возраст, рост и вес игроков
#       2 df.loc[df['Age'] == 0, 'Age'] = [44, 49, 74, 52, 48, 58, 80, 43, 38, 57]
# ----> 3 df.loc[df['Height'] == 0, 'Height'] = [175, 175, 181]
#       4 df.loc[df['Weight'] == 0, 'Weight'] = [86, 71, 76, 69, 69, 80]
#       6 df.Age.shape
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1688, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1685 # align and set the values
#    1686 if take_split_path:
#    1687     # We have to operate column-wise
# -> 1688     self._setitem_with_indexer_split_path(indexer, value, name)
#    1689 else:
#    1690     self._setitem_single_block(indexer, value, name)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1770, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1767         self._setitem_single_column(ilocs[0], value, pi)
#    1769     else:
# -> 1770         raise ValueError(
#    1771             "Must have equal len keys and value "
#    1772             "when setting with an iterable"
#    1773         )
#    1775 else:
#    1776
#    1777     # scalar value
#    1778     for loc in ilocs:
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
(df['Age'] == 0).sum()
# Out:
# 10

# %%
(df == 0).sum()
# Out:
# Name                0
# Card Type           0
# Nation              0
# Club                0
# League              0
# Skills              0
# W/F                 0
# W/R                 0
# Foot                0
# Age                12
# Height              0
# Weight              3
# Body Type           0
# Position            0
# Alt. Position       0
# Rating              0
# PAC                 0
# SHO                 0
# PAS                 0
# DRI                 0
# DEF                 0
# PHY                 0
# Price             352
# Acceleration        0
# Sprint Speed        0
# Positioning         0
# Finishing           0
# Shot Power          0
# Long Shots          0
# Volleys             0
# Penalties           0
# Vision              0
# Crossing            0
# FK. Acc.            0
# Short Pass          0
# Long Pass           0
# Curve               0
# Agility             0
# Balance             0
# Reactions           0
# Ball Control        0
# Dribbling           0
# Composure           0
# Interceptions       0
# Heading Acc.        0
# Def. Awareness      0
# Stand Tackle        0
# Slide Tackle        0
# Jumping             0
# Stamina             0
# Strength            0
# Aggression          0
# dtype: int64

# %%
# Цену мы трогать не будем, так как эти игроков можно было получить только выполнив специальные задания или пожертвовав других игроков
# Поэтому мы их отнесем в отдельную таблицу
no_trade_players = df[df['Price'] == 0]
df = df.drop(df[df['Price'] == 0].index)

# %%
(df != 0).any().any()
# Out:
# True

# %%
# У всех базовых карточек по умолчанию было указан тип "Non-Inform", поэтому заменим на оригинальный вид

conditions = [
    (df['Card Type'] == 'Non-Inform') & (df['Rating'] > 74),
    (df['Card Type'] == 'Non-Inform') & (df['Rating'] >= 65) & (df['Rating'] <= 74),
    (df['Card Type'] == 'Non-Inform') & (df['Rating'] < 65)
]
values = ['Gold', 'Silver', 'Bronze']

df['Card Type'] = np.select(conditions, values, df['Card Type'])

# %% [markdown]
# ### Анализ и визуализация данных

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Card Type', color='steelblue')
plt.title('Количество игроков по типу карточки', fontsize=20)
plt.xlabel('Тип карточоки', fontsize=16)
plt.ylabel('Количество игроков', fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
# !pip3 install geopandas
# Out:
# Requirement already satisfied: geopandas in ./opt/anaconda3/lib/python3.9/site-packages (0.13.0)
# Requirement already satisfied: shapely>=1.7.1 in ./opt/anaconda3/lib/python3.9/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: pyproj>=3.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from geopandas) (3.5.0)
# Requirement already satisfied: fiona>=1.8.19 in ./opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.9.3)
# Requirement already satisfied: packaging in ./opt/anaconda3/lib/python3.9/site-packages (from geopandas) (21.3)
# Requirement already satisfied: pandas>=1.1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: attrs>=19.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (21.4.0)
# Requirement already satisfied: click-plugins>=1.0 in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: click~=8.0 in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (8.0.4)
# Requirement already satisfied: munch>=2.3.2 in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (3.0.0)
# Requirement already satisfied: cligj>=0.5 in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: importlib-metadata in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (4.11.3)
# Requirement already satisfied: certifi in ./opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (2021.10.8)
# Requirement already satisfied: six in ./opt/anaconda3/lib/python3.9/site-packages (from munch>=2.3.2->fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->geopandas) (1.21.5)
# Requirement already satisfied: zipp>=0.5 in ./opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata->fiona>=1.8.19->geopandas) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./opt/anaconda3/lib/python3.9/site-packages (from packaging->geopandas) (3.0.4)

# %%
import geopandas as gpd

nation_counts = df['Nation'].value_counts() # Подсчет статистики по распределению национальностей игроков
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres')) # Загрузка базы данных по странам с их местоположением на карте
merged = world.merge(nation_counts, left_on='name', right_index=True) # Объединение статистики по игрокам и расположения стран

# Построение карты
fig, ax = plt.subplots(figsize=(25, 15))
merged.plot(column='Nation', cmap='Reds', ax=ax, edgecolor='0.8', legend=True,
            legend_kwds={'shrink': 0.6, 'aspect': 30}) # Настройка размера легенды справа

# Обозначения на карте
ax.set_title('Количество игроков из каждой нации', fontsize=16)
ax.set_xlabel('Доли игроков', fontsize=14)
ax.set_ylabel('Страны', fontsize=14)
ax.tick_params(axis='both', labelsize=12)

plt.show()
# Out:
# /var/folders/8z/vdz_vf5x0td_rrfx9pj75j880000gn/T/ipykernel_15571/1548177007.py:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres')) # Загрузка базы данных по странам с их местоположением на карте

# %%
world # База данных по расположению стран
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# 173     622137.0         Europe                Montenegro    MNE        5542
# 174    1794248.0         Europe                    Kosovo    -99        7926
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
# 176   11062113.0         Africa                  S. Sudan    SSD       11998
#
#                                               geometry
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..                                                 ...
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [177 rows x 6 columns]

# %% [markdown]
# - Карта плохо показывает распределение игроков по странам в более мелком масштабе

# %%
# !pip3 install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
import matplotlib.pyplot as plt
import squarify
import numpy as np

min_count = 15 # минимальное число игроков страны, при котором страна будет видна на карте
filtered_nation_counts = nation_counts[nation_counts >= min_count]

sizes = filtered_nation_counts.values # массив значений
labels = filtered_nation_counts.index # массив индексов
colors = plt.cm.Spectral(np.linspace(0, 1, len(labels))) # палитра цветов

fig, ax = plt.subplots(figsize=(12, 8))
squarify.plot(sizes=sizes, label=labels,color=colors)

# Настройка внешнего вида
plt.axis('off')
plt.title('Количество игроков из каждой нации', fontsize=16)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='League', color='steelblue')
plt.title('Количество игроков в каждой лиге', fontsize=20)
plt.xlabel('Лига', fontsize=16)
plt.ylabel('Количество игроков', fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
# Визуализация статистики по ведущей ноге у различных игроков
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Foot', color='steelblue')
plt.title('Ведущая нога у игроков', fontsize=16)
plt.xlabel('Нога', fontsize=14)
plt.ylabel('Количество игроков', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# Визуализация статистика по ведущей ноге у различных игроков
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Height', color='steelblue')
plt.title('Распределение значений роста игроков', fontsize=16)
plt.xlabel('Height (дюймы)', fontsize=14)
plt.ylabel('Частота', fontsize=14)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Weight', color='steelblue')
plt.title('Распределение значений веса игроков', fontsize=16)
plt.xlabel('Weight (кг)', fontsize=14)
plt.ylabel('Частота', fontsize=14)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
df.loc[df['Weight'] == 0, 'Weight'] = df['Weight'].mean()

# %%
age_grouped_2 = pd.cut(df['Age'], bins=range(0, 101, 2), right=False) # объединение игроков в интервалы длнною в 2 по возрасту

plt.figure(figsize=(12, 6))
sns.countplot(data=df, x=age_grouped_5, color='steelblue')
plt.title('Распределение возрастов игроков', fontsize=16)
plt.xlabel('Интервалы возрастов', fontsize=14)
plt.ylabel('Количество игроков', fontsize=14)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Rating', bins=10, color='steelblue')
plt.xlabel('Рейтигш', fontsize=14)
plt.ylabel('Количество', fontsize=14)
plt.title('Распределение игроков по рейтингу', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=False, cmap='coolwarm', cbar=False)
plt.title('Correlation Matrix', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# - Матрица корелляции дает хорошее общее представление о данных, но ее не очень удобно применять, так как на ней слишком много малозначимой информации

# %%
# Посчитаем топ 10 корелляций по всей таблицы
correlation_matrix = df.corr().abs()
correlation_matrix = correlation_matrix[correlation_matrix != 1] # Корелляция столбца с самим собой нам не нужна
top_correlations = correlation_matrix.unstack().sort_values(ascending=False)
top_correlations = top_correlations[top_correlations != 0]

# Удаление дублирующихся пар признаков
top_correlations = top_correlations[~top_correlations.index.duplicated()]

# Вывод топ-10 корреляций
top_correlations = top_correlations.head(10)

plt.figure(figsize=(12, 6))
top_correlations.plot(kind='bar', color='steelblue')
plt.title('Пары признаков с наибольшей корелляцией между собой', fontsize=16)
plt.xlabel('Пары признаков', fontsize=14)
plt.ylabel('Корреляция', fontsize=14)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# Посчитаем корелляцию каждого признака с ценой карточки игрока
plt.figure(figsize=(12, 6))
correlation_with_price = df.corr()['Price'].drop('Price').sort_values()
correlation_with_price.plot(kind='bar', color='steelblue')
plt.title('Корелляция каждого из признака с ценой карточки игрока', fontsize=16)
plt.xlabel('Признак', fontsize=14)
plt.ylabel('Корреляция с ценой', fontsize=14)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# Посмоотрим на распределение стоимостей игроков

plt.figure(figsize=(12, 8))
counts_grouped_2 = pd.cut(df['Price'], bins=range(0, 2000, 50), right=False)

counts_grouped_2.value_counts().sort_index().plot(kind='bar')
plt.xlabel('Цена')
plt.ylabel('Число игроков')
plt.title('Распределение стоимостей карточек игроков')
plt.xticks(rotation=90)
plt.show()

# %%
counts_grouped_2
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1582    NaN
# 1583    NaN
# 1584    NaN
# 1585    NaN
# 1586    NaN
# Name: Price, Length: 1230, dtype: category
# Categories (39, interval[int64, left]): [[0, 50) < [50, 100) < [100, 150) < [150, 200) ... [1750, 1800) < [1800, 1850) < [1850, 1900) < [1900, 1950)]

# %% [markdown]
# ### Кодирование данных

# %% [markdown]
# - Для дальнейшней работы с алгоритмами машинного обучения нам необходимо закодировать категориальные переменные
# - В выборе между Label Encoding и One-hot-encoding был выбран метод One-hot-encoding, так как он более универсальный и не ранжирует признаки
# - Наличие отдельного столбца под каждое из значений категориального признака позволяет алгоритму лучше работать с весами

# %%
df_initial = df.copy()

categorical_columns = ['Card Type', 'Nation', 'Club', 'League', 'W/R', 'Foot', 'Height', 'Weight', 'Body Type', 'Position', 'Alt. Position']
df_categorical_encoded = pd.get_dummies(df[categorical_columns])

# Объединение закодированных столбцов с исходным DataFrame
df_encoded = pd.concat([df_initial, df_categorical_encoded], axis=1)

# Удаление исходных категориальных столбцов
df_encoded.drop(categorical_columns, axis=1, inplace=True)

# %%
df_encoded
